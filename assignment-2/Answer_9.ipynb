# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Desktop\chrome\chromedriver.exe")

# %%
driver.get("https://www.jagranjosh.com/")
driver.maximize_window()

# %%
gk=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[9]/a")
gk.click()

# %%
pm=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[29]/div/div/ul/li/ul[2]/li[11]/a")
pm.click()

# %%
pm_name=[]
pm_db=[]
pm_term=[]
pm_remark=[]

# %%
 # scraping title name from the given page
name_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"][1]/table/tbody/tr/td[2]')
for i in name_tags:
    name=i.text
    pm_name.append(name)
 
    # scraping dead-born data from the given page
db_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"][1]/table/tbody/tr/td[3]')
for i in db_tags:
    db=i.text
    pm_db.append(db)
    
 # scraping term of office data from the given page
term_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"][1]/table/tbody/tr/td[4]')
for i in term_tags:
    term=i.text
    pm_term.append(term)
    
     # scraping remark data from the given page
remark_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"][1]/table/tbody/tr/td[5]')
for i in remark_tags:
    remark=i.text
    pm_remark.append(remark)

# %%
print(len(pm_name),len(pm_db),len(pm_term),len(pm_remark))
# Out:
# 18 18 18 18

# %%
import pandas as pd
df=pd.DataFrame({'List of Prime Ministers':pm_name,'Dead-Born':pm_db,'Term of Office':pm_term,'Remarks':pm_remark})
df
# Out:
#         List of Prime Ministers     Dead-Born  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                                        Term of Office  \
# ...
