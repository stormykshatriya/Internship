# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Desktop\chrome\chromedriver.exe")

# %%
driver.get("https://github.com/")
driver.maximize_window()

# %%
source=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
source.click()
trending=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a")
trending.click()

# %%
r_title = []
r_description = []
r_contributors = []
r_language = []

# %%
title_tags=driver.find_elements(By.XPATH,'//span[@class="text-normal"]')
for i in title_tags:
        title=i.text
        r_title.append(title)
    

description_tags=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in description_tags:
        description=i.text
        r_description.append(title)
        

contributors_tags=driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"][1]')
for i in contributors_tags:
        contributors=i.text
        r_contributors.append(contributors)


language_tags=driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
for i in language_tags:
        language=i.text
        r_language.append(language)

# %%
print(len(r_title),len(r_description),len(r_contributors),len(r_language))
# Out:
# 25 24 25 22

# %%
import pandas as pd
a = {'Title':r_title,'Description':r_description,'Contributors':r_contributors,'Language':r_language}
df=pd.DataFrame.from_dict(a, orient='index')
df
# Out:
#                            0                1                2   \
# Title                xtekky /      mitsuhiko /   sindresorhus /
# Description   farizrahman4u /  farizrahman4u /  farizrahman4u /
# Contributors            9,179            3,391          250,947
# Language               Python             Rust           Python
#
#                            3                4                5   \
# Title               Josh-XT /    whoiskatrin /        Snaacky /
# Description   farizrahman4u /  farizrahman4u /  farizrahman4u /
# Contributors              757            1,439               86
# Language           TypeScript           Python       TypeScript
#
#                            6                7                  8   \
# Title               lvwzhen /        GreyDGL /  BigBrotherTrade /
# Description   farizrahman4u /  farizrahman4u /    farizrahman4u /
# Contributors            2,457              849                598
# ...
